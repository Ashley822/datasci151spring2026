# %% [markdown]
# This is my first Jupyter notebook
#
# <font size = "5">
# This is my first Jupyter notebook
#
#
# <font size = "10">
#
# This is my first Jupyter notebook

# %%
print("My name is Ashley Lin")
# Out:
# My name is Ashley Lin
